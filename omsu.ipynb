# %%
import pandas as pd

# %%
df = pd.read_excel('Динамика 2024-07-03 08_46_27.xlsx')

# %%
df
# Out:
#     Номер пожара Дата возникновения пожара ID Карты  \
# 0   10106144\001       28.06.2024 10:05:00     id32
# 1   10106144\002       28.06.2024 10:18:00     id32
# 2   10106103\002       28.06.2024 10:40:00      id0
# 3   10106116\015       28.06.2024 14:30:00     id54
# 4   10106144\003       28.06.2024 15:20:00     id32
# 5   10106144\004       28.06.2024 15:35:00     id32
# 6   10106144\005       28.06.2024 15:50:00     id32
# 7   10106144\007       28.06.2024 16:01:00     id32
# 8   10106144\008       28.06.2024 16:16:00     id32
# 9   10106144\009       28.06.2024 16:22:00     id32
# 10  10106144\010       28.06.2024 16:37:00     id32
# 11  10106103\003       29.06.2024 09:55:00      id0
# 12  10106147\001       29.06.2024 11:07:00     id40
# 13  10106161\001       29.06.2024 11:55:00      id0
# 14  10106161\002       29.06.2024 12:19:00      id0
# 15  10106103\004       29.06.2024 13:30:00      id0
# 16  10106132\005       29.06.2024 14:00:00     id21
# ...
