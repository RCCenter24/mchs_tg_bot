# %%
import pandas as pd

# %%
from xlsx2csv import Xlsx2csv

# %%
from glob import glob

# %%
import os

# %%
file_path = os.path.join('saved_files/', 'Динамика 2024-07-05 08_46_23.xlsx')

# %%
Xlsx2csv(file_path, outputencoding="utf-8").convert("myfile.csv")

# %%
pd.read_csv('myfile.csv')
# Out:
#     Номер пожара Дата возникновения пожара ID Карты  \
# 0   10106144\003       28.06.2024 15:20:00     id32
# 1   10106144\004       28.06.2024 15:35:00     id32
# 2   10106144\007       28.06.2024 16:01:00     id32
# 3   10106144\008       28.06.2024 16:16:00     id32
# 4   10106147\001       29.06.2024 11:07:00     id40
# 5   10106161\001       29.06.2024 11:55:00      id0
# 6   10106161\002       29.06.2024 12:19:00      id0
# 7   10106103\004       29.06.2024 13:30:00      id0
# 8   10106161\003       29.06.2024 16:10:00      id0
# 9   10106150\009       29.06.2024 17:25:00      id0
# 10  10106161\004       30.06.2024 11:49:00      id0
# 11  10106138\015       01.07.2024 20:45:00     id54
# 12  10106150\011       02.07.2024 10:35:00      id0
# 13  10106138\017       02.07.2024 12:05:00     id54
# 14  10106161\005       02.07.2024 12:10:00      id0
# 15  10106150\012       02.07.2024 14:05:00      id0
# 16  10106150\013       02.07.2024 14:35:00      id0
# ...

# %%
my_dict = p.get_dict(file_name=file_path, name_columns_by_row=0)
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[6], line 1
#
# ----> 1 my_dict = p.get_dict(file_name=file_path, name_columns_by_row=0)
#
#
#
# File ~/python_projects/mchs_tg_bot/.venv/lib/python3.12/site-packages/pyexcel/core.py:158, in get_dict(name_columns_by_row, **keywords)
#
#     141 @append_doc(docs.GET_DICT)
#
#     142 def get_dict(name_columns_by_row=0, **keywords):
#
#     143     """
#
#     144     Obtain a dictionary from an excel source
#
#     145
#
#    (...)
#
#     156
#
#     157     """
#
# --> 158     sheet = get_sheet(name_columns_by_row=name_columns_by_row, **keywords)
#
#     159     return sheet.to_dict()
#
#
#
# File ~/python_projects/mchs_tg_bot/.venv/lib/python3.12/site-packages/pyexcel/core.py:37, in get_sheet(**keywords)
#
#      35     if field in keywords:
#
#      36         sheet_params[field] = keywords.pop(field)
#
# ...

# %%
my_dict = p.get_dict(file_name=file_path, name_columns_by_row=0)
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[6], line 1
#
# ----> 1 my_dict = p.get_dict(file_name=file_path, name_columns_by_row=0)
#
#
#
# File ~/python_projects/mchs_tg_bot/.venv/lib/python3.12/site-packages/pyexcel/core.py:158, in get_dict(name_columns_by_row, **keywords)
#
#     141 @append_doc(docs.GET_DICT)
#
#     142 def get_dict(name_columns_by_row=0, **keywords):
#
#     143     """
#
#     144     Obtain a dictionary from an excel source
#
#     145
#
#    (...)
#
#     156
#
#     157     """
#
# --> 158     sheet = get_sheet(name_columns_by_row=name_columns_by_row, **keywords)
#
#     159     return sheet.to_dict()
#
#
#
# File ~/python_projects/mchs_tg_bot/.venv/lib/python3.12/site-packages/pyexcel/core.py:37, in get_sheet(**keywords)
#
#      35     if field in keywords:
#
#      36         sheet_params[field] = keywords.pop(field)
#
# ...

# %%
df
# Out:
#     Номер пожара Дата возникновения пожара ID Карты  \
# 0   10106144\001       28.06.2024 10:05:00     id32
# 1   10106144\002       28.06.2024 10:18:00     id32
# 2   10106103\002       28.06.2024 10:40:00      id0
# 3   10106116\015       28.06.2024 14:30:00     id54
# 4   10106144\003       28.06.2024 15:20:00     id32
# 5   10106144\004       28.06.2024 15:35:00     id32
# 6   10106144\005       28.06.2024 15:50:00     id32
# 7   10106144\007       28.06.2024 16:01:00     id32
# 8   10106144\008       28.06.2024 16:16:00     id32
# 9   10106144\009       28.06.2024 16:22:00     id32
# 10  10106144\010       28.06.2024 16:37:00     id32
# 11  10106103\003       29.06.2024 09:55:00      id0
# 12  10106147\001       29.06.2024 11:07:00     id40
# 13  10106161\001       29.06.2024 11:55:00      id0
# 14  10106161\002       29.06.2024 12:19:00      id0
# 15  10106103\004       29.06.2024 13:30:00      id0
# 16  10106132\005       29.06.2024 14:00:00     id21
# ...
